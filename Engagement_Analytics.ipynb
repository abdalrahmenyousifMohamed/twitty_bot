# %% [markdown]
# <a href="https://colab.research.google.com/github/abdalrahmenyousifMohamed/twitty_bot/blob/main/Engagement_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/TanaMongeau.csv')
df.head()
# Out:
#                                              content  \
# 0  @BryceHall hmmmmmm down but for the individual...
# 1  OMG I WAS GONNA PITCH THAT TO YOU \n\nof live ...
# 2  i’m on my way i’m gambling ur money 😍😍😍 https:...
# 3  @kxrennicole no i’m doing it for a tiktok i kn...
# 4              i am so funny https://t.co/Wry1RQLmj8
#
#                        created_at                       date  likeCount  \
# 0  Fri Dec 23 22:40:24 +0000 2022  2022-12-23 22:40:24+00:00        147
# 1  Fri Dec 23 01:28:56 +0000 2022  2022-12-23 01:28:56+00:00        374
# 2  Thu Dec 22 02:10:19 +0000 2022  2022-12-22 02:10:19+00:00        382
# 3  Thu Dec 22 02:07:28 +0000 2022  2022-12-22 02:07:28+00:00          4
# 4  Thu Dec 22 02:05:34 +0000 2022  2022-12-22 02:05:34+00:00       8627
#
#                                                media  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df = pd.read_csv('/content/gender-classifier-DFE-791531.csv',encoding="latin1")
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ...                                       profileimage  \
# 0    12/5/13 1:48  ...  https://pbs.twimg.com/profile_images/414342229...
# ...

# %%
#df['profile_yn_gold'].fillna('no', inplace=True)

df['tweet_created']
# Out:
# 0        10/26/15 12:40
# 1        10/26/15 12:40
# 2        10/26/15 12:40
# 3        10/26/15 12:40
# 4        10/26/15 12:40
#               ...
# 20045    10/26/15 13:20
# 20046    10/26/15 12:40
# 20047    10/26/15 13:20
# 20048    10/26/15 12:40
# 20049    10/26/15 13:19
# Name: tweet_created, Length: 20050, dtype: object

# %%
df.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'gender', 'gender:confidence', 'profile_yn',
#        'profile_yn:confidence', 'created', 'description', 'fav_number',
#        'gender_gold', 'link_color', 'name', 'profile_yn_gold', 'profileimage',
#        'retweet_count', 'sidebar_color', 'text', 'tweet_coord', 'tweet_count',
#        'tweet_created', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %% [markdown]
# - gender: one of male, female, or brand (for non-human profiles)
#
#
# - description: the user's profile description
# - fav_number: number of tweets the user has favorited
# - name: the user's name
# - profile_yn_gold: whether the profile y/n value is golden
# - retweet_count: number of times the user has retweeted (or possibly, been retweeted)
# - text: text of a random one of the user's tweets
#
# - tweet_count: number of tweets that the user has posted
# - tweet_created: when the random tweet (in the text column) was created
# - tweet_id: the tweet id of the random tweet

# %%
new_df = df[['gender','name','tweet_created','text','tweet_id','description','profile_yn_gold','tweet_count','retweet_count','fav_number']]

# %%
new_df.set_index(['tweet_created']).head()
# Out:
#                 gender            name  \
# tweet_created
# 10/26/15 12:40    male         sheezy0
# 10/26/15 12:40    male     DavdBurnett
# 10/26/15 12:40    male  lwtprettylaugh
# 10/26/15 12:40    male     douggarland
# 10/26/15 12:40  female    WilfordGemma
#
#                                                              text  \
# tweet_created
# 10/26/15 12:40  Robbie E Responds To Critics After Win Against...
# 10/26/15 12:40  ÛÏIt felt like they were my friends and I was...
# 10/26/15 12:40  i absolutely adore when louis starts the songs...
# 10/26/15 12:40  Hi @JordanSpieth - Looking at the url - do you...
# 10/26/15 12:40  Watching Neighbours on Sky+ catching up with t...
#
#                     tweet_id  \
# tweet_created
# 10/26/15 12:40  6.587300e+17
# 10/26/15 12:40  6.587300e+17
# 10/26/15 12:40  6.587300e+17
# 10/26/15 12:40  6.587300e+17
# 10/26/15 12:40  6.587300e+17
#
#                                                       description  \
# tweet_created
# ...

# %%
# date_format = "%m/%d/%y %H:%M"
# from datetime import datetime
# # Loop through the DataFrame and convert the 'DateStrings' column
# for index, row in new_df.iterrows():
#     date_string = row['tweet_created']
#     date_object = datetime.strptime(date_string, date_format)
#     new_df.at[index, 'tweet_created'] = date_object

# # Print the modified DataFrame

# %%
new_df.set_index('tweet_created', inplace=True)
new_df.head()
# Out:
#                      gender            name  \
# tweet_created
# 2015-10-26 12:40:00    male         sheezy0
# 2015-10-26 12:40:00    male     DavdBurnett
# 2015-10-26 12:40:00    male  lwtprettylaugh
# 2015-10-26 12:40:00    male     douggarland
# 2015-10-26 12:40:00  female    WilfordGemma
#
#                                                                   text  \
# tweet_created
# 2015-10-26 12:40:00  Robbie E Responds To Critics After Win Against...
# 2015-10-26 12:40:00  ÛÏIt felt like they were my friends and I was...
# 2015-10-26 12:40:00  i absolutely adore when louis starts the songs...
# 2015-10-26 12:40:00  Hi @JordanSpieth - Looking at the url - do you...
# 2015-10-26 12:40:00  Watching Neighbours on Sky+ catching up with t...
#
#                          tweet_id  \
# tweet_created
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
#
# ...

# %%
len(new_df)
# Out:
# 20050

# %%
new_df.head()
# Out:
#                      gender            name  \
# tweet_created
# 2015-10-26 12:40:00    male         sheezy0
# 2015-10-26 12:40:00    male     DavdBurnett
# 2015-10-26 12:40:00    male  lwtprettylaugh
# 2015-10-26 12:40:00    male     douggarland
# 2015-10-26 12:40:00  female    WilfordGemma
#
#                                                                   text  \
# tweet_created
# 2015-10-26 12:40:00  Robbie E Responds To Critics After Win Against...
# 2015-10-26 12:40:00  ÛÏIt felt like they were my friends and I was...
# 2015-10-26 12:40:00  i absolutely adore when louis starts the songs...
# 2015-10-26 12:40:00  Hi @JordanSpieth - Looking at the url - do you...
# 2015-10-26 12:40:00  Watching Neighbours on Sky+ catching up with t...
#
#                          tweet_id  \
# tweet_created
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
#
# ...

# %%
new_df.rename(columns={'description': 'BIO', 'text': 'user_tweet','fav_number':'liked_num'}, inplace=True)
# Out:
# <ipython-input-51-1a7525660880>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'description': 'BIO', 'text': 'user_tweet','fav_number':'liked_num'}, inplace=True)

# %%
new_df.head()
# Out:
#                      gender            name  \
# tweet_created
# 2015-10-26 12:40:00    male         sheezy0
# 2015-10-26 12:40:00    male     DavdBurnett
# 2015-10-26 12:40:00    male  lwtprettylaugh
# 2015-10-26 12:40:00    male     douggarland
# 2015-10-26 12:40:00  female    WilfordGemma
#
#                                                             user_tweet  \
# tweet_created
# 2015-10-26 12:40:00  Robbie E Responds To Critics After Win Against...
# 2015-10-26 12:40:00  ÛÏIt felt like they were my friends and I was...
# 2015-10-26 12:40:00  i absolutely adore when louis starts the songs...
# 2015-10-26 12:40:00  Hi @JordanSpieth - Looking at the url - do you...
# 2015-10-26 12:40:00  Watching Neighbours on Sky+ catching up with t...
#
#                          tweet_id  \
# tweet_created
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
# 2015-10-26 12:40:00  6.587300e+17
#
# ...

# %%
new_df['name'].value_counts()
# Out:
# TudoSobreQuase    30
# 94heskind         27
# Map_Game          24
# naijama           18
# aSEATaxiCab       15
#                   ..
# 06042jcsa          1
# rumucijaseho       1
# 02532gnlc          1
# stwc29530          1
# Gbuschrist         1
# Name: name, Length: 18795, dtype: int64

# %%
new_df.columns
# Out:
# Index(['gender', 'name', 'user_tweet', 'tweet_id', 'BIO', 'profile_yn_gold',
#        'tweet_count', 'retweet_count', 'liked_num'],
#       dtype='object')

# %%
new_df.to_csv('twitty.csv')
